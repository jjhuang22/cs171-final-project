# %%
import numpy as np
import pandas as pd
import json

# %%
# companies = pd.read_csv("companies_final.csv", encoding = 'ISO-8859-1').drop(columns = ['Unnamed: 0'])
# acquisitions = pd.read_csv("acquisitions_final.csv").drop(columns = ['Unnamed: 0'])

# %%
# acquisitions_df = acquisitions[acquisitions['acquirer_name'].isin(desiredCompanies)]

# %%
# acquisitions_df.sort_values(by = ['acquirer_market'], inplace=True)
# acquisitions_df.transpose()

# %%
# acquisitions_df.to_csv('changeMarket.csv')

# %%
# desiredMarkets = ['Service Provider']

# %%
desiredCompanies = ['Google', 'Yahoo!', 'AOL', 'Oracle Corporation', 'Microsoft', 'Salesforce', 
                    'Facebook', 'Hewlett-Packard', 'Cisco', 'Apple']
desiredMarkets = ['Service Provider', 'Social Media', 'Enterprise Software', 'Software', "Hardware + Software"]

# %%
acquisitions_df = pd.read_csv("changedMarket.csv").drop(columns = ['Unnamed: 0'])

# %%
# layer0 = []
# for i in desiredMarkets: # 1. acquirer market 
#     df1 = acquisitions_df[acquisitions_df['acquirer_market'] == i]
#     companiesInMarket = set(df1['acquirer_name'].values) # 2. acquirer
    
#     layer1 = []
#     for j in companiesInMarket:
#         df2 = df1[df1['acquirer_name'] == j]
#         marketAcquired = set(df2['company_market'].values) # 3. markets acquired
#         layer2 = []
        
#         for k in marketAcquired: 
#             layer3 = []
#             df3 = df2[df2['company_market'] == k]
#             companies = df3['company_name'].values
#             for l in companies:
#                 layer3.append({"name": l, "size": int(df3[df3['company_name'] == l]['price_amount'].values[0])})
           
#             layer2.append({"name": k, "children": layer3})
         
#         layer1.append({"name": j, "children": layer2})

    
#     layer0.append({"name": i, "children": layer1})

# finaljson = {"name": "acquisitions", "children": layer0}

# %%
layer0 = []
for i in desiredMarkets: # 1. acquirer market 
    valuation = 0
    df1 = acquisitions_df[acquisitions_df['acquirer_market'] == i]
    companiesInMarket = set(df1['acquirer_name'].values) # 2. acquirer
    
    layer1 = []
    for j in companiesInMarket:
        df2 = df1[df1['acquirer_name'] == j]
        marketAcquired = set(df2['company_market'].values) # 3. markets acquired
        layer2 = []
        
        for k in marketAcquired: 
            layer3 = []
            df3 = df2[df2['company_market'] == k]
            companies = df3['company_name'].values
            for l in companies:
                layer3.append({"name": l, "size": int(df3[df3['company_name'] == l]['price_amount'].values[0])})
                valuation += int(df3[df3['company_name'] == l]['price_amount'].values[0])
           
            layer2.append({"name": k, "children": layer3})
         
        layer1.append({"name": j, "children": layer2})

    
    layer0.append({"name": i, "value": valuation, "children": layer1})

finaljson = {"name": "acquisitions", "children": layer0}

# %%
finaljson
# Out:
# {'name': 'acquisitions',
#  'children': [{'name': 'Service Provider',
#    'value': 49292400000,
#    'children': [{'name': 'Yahoo!',
#      'children': [{'name': 'Mobile',
#        'children': [{'name': 'Tomfoolery', 'size': 16000000},
#         {'name': 'Flurry', 'size': 200000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'Aviate', 'size': 80000000},
#         {'name': 'Zimbra', 'size': 350000000},
#         {'name': 'Xobni', 'size': 48000000},
#         {'name': 'Verdisoft', 'size': 93000000},
#         {'name': 'Inktomi', 'size': 235000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'Yeye Aduhay', 'size': 10000000},
#         {'name': 'Musicmatch', 'size': 160000000},
#         {'name': 'Associated Content', 'size': 90000000},
#         {'name': 'eGroups', 'size': 432000000},
#         {'name': 'Upcoming', 'size': 1000000}]},
#       {'name': 'E-Commerce',
#        'children': [{'name': 'Rivals.com', 'size': 100000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'Right Media', 'size': 850000000},
#         {'name': 'BrightRoll', 'size': 640000000},
#         {'name': 'BlueLithium', 'size': 300000000},
#         {'name': 'interclick', 'size': 270000000},
#         {'name': '5to1', 'size': 30000000}]},
#       {'name': 'Media',
#        'children': [{'name': 'Snip.it', 'size': 10000000},
#         {'name': 'Dapper', 'size': 55000000},
#         {'name': 'Broadcast.com', 'size': 5700000000},
#         {'name': 'Launch Media', 'size': 12000000},
#         {'name': 'Xoopit', 'size': 20000000},
#         {'name': 'Qwiki', 'size': 50000000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'Rockmelt', 'size': 65000000},
#         {'name': 'MessageMe', 'size': 30000000},
#         {'name': 'Tumblr', 'size': 1100000000}]},
#       {'name': 'Web Hosting',
#        'children': [{'name': 'GeoCities', 'size': 2870000000}]}]},
#     {'name': 'AOL',
#      'children': [{'name': 'Video',
#        'children': [{'name': 'Adap.tv', 'size': 405000000},
#         {'name': 'Vidible', 'size': 50000000},
#         {'name': '5min Media', 'size': 65000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'InfoInterActive', 'size': 28200000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'Userplane', 'size': 40000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'Surphace', 'size': 25000000},
#         {'name': 'MapQuest', 'size': 1100000000},
#         {'name': 'Going', 'size': 10000000}]},
#       {'name': 'Service Provider',
#        'children': [{'name': 'Netscape', 'size': 4200000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'Tacoda', 'size': 275000000},
#         {'name': 'buy.at', 'size': 125000000},
#         {'name': 'Advertising.com', 'size': 435000000},
#         {'name': 'Gravity', 'size': 90700000},
#         {'name': 'Convertro', 'size': 101000000}]},
#       {'name': 'Media',
#        'children': [{'name': 'Patch', 'size': 7000000},
#         {'name': 'Quigo', 'size': 363000000},
#         {'name': 'The Huffington Post', 'size': 315000000},
#         {'name': 'MovieFone', 'size': 525000000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'Bebo', 'size': 850000000}]}]},
#     {'name': 'Google',
#      'children': [{'name': 'Media',
#        'children': [{'name': 'Slide', 'size': 182000000}]},
#       {'name': 'Mobile',
#        'children': [{'name': 'Bump Technologies', 'size': 30000000},
#         {'name': 'Motorola Mobility', 'size': 12500000000},
#         {'name': 'GrandCentral', 'size': 60000000}]},
#       {'name': 'Video',
#        'children': [{'name': 'YouTube', 'size': 1650000000},
#         {'name': 'Omnisio', 'size': 15000000},
#         {'name': 'On2 Technologies', 'size': 130000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'Android', 'size': 50000000},
#         {'name': 'PeakStream', 'size': 20300000},
#         {'name': 'Divide', 'size': 120000000},
#         {'name': 'BumpTop', 'size': 35000000},
#         {'name': 'Flutter', 'size': 40000000},
#         {'name': 'Global IP Solutions', 'size': 68200000}]},
#       {'name': 'Hardware + Software',
#        'children': [{'name': 'Widevine Technologies', 'size': 160000000},
#         {'name': 'Nest Labs', 'size': 3200000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'Postini', 'size': 625000000},
#         {'name': 'FeedBurner', 'size': 100000000},
#         {'name': 'DocVerse', 'size': 25000000},
#         {'name': 'Channel Intelligence', 'size': 125000000},
#         {'name': 'Adscape', 'size': 23000000},
#         {'name': 'Zagat', 'size': 151000000}]},
#       {'name': 'Service Provider',
#        'children': [{'name': 'Aardvark', 'size': 50000000}]},
#       {'name': 'Travel',
#        'children': [{'name': 'Waze', 'size': 996000000},
#         {'name': 'ITA Software', 'size': 700000000}]},
#       {'name': 'E-Commerce',
#        'children': [{'name': 'Jambool', 'size': 70000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'DoubleClick', 'size': 3100000000},
#         {'name': 'AdMob', 'size': 750000000},
#         {'name': 'Invite Media', 'size': 80000000},
#         {'name': 'Admeld', 'size': 400000000},
#         {'name': 'Gizmo5', 'size': 30000000}]},
#       {'name': 'Analytics',
#        'children': [{'name': 'Skybox Imaging', 'size': 500000000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'Meebo', 'size': 100000000},
#         {'name': 'Wildfire, a division of Google', 'size': 350000000},
#         {'name': 'The Dealmap', 'size': 30000000}]}]}]},
#   {'name': 'Social Media',
#    'value': 22885470000,
#    'children': [{'name': 'Facebook',
#      'children': [{'name': 'Mobile',
#        'children': [{'name': 'Onavo', 'size': 150000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'Parse', 'size': 90000000},
#         {'name': 'Chai Labs', 'size': 10000000}]},
#       {'name': 'Hardware + Software',
#        'children': [{'name': 'Oculus VR', 'size': 2000000000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'LiveRail', 'size': 500000000}]},
#       {'name': 'Travel', 'children': [{'name': 'Nextstop', 'size': 2500000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'WhatsApp', 'size': 19000000000},
#         {'name': 'Branch', 'size': 15000000},
#         {'name': 'FriendFeed', 'size': 47500000},
#         {'name': 'Instagram', 'size': 1010470000},
#         {'name': 'Hot Potato', 'size': 10000000},
#         {'name': 'Bolt | Peters', 'size': 50000000}]}]}]},
#   {'name': 'Enterprise Software',
#    'value': 56857500000,
#    'children': [{'name': 'Salesforce',
#      'children': [{'name': 'Social Media',
#        'children': [{'name': 'Salesforce Buddy Media', 'size': 689000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'ExactTarget', 'size': 2500000000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'Desk', 'size': 50000000},
#         {'name': 'Salesforce Radian6', 'size': 326000000},
#         {'name': 'InStranet', 'size': 31500000},
#         {'name': 'RelateIQ', 'size': 390000000},
#         {'name': 'Heroku', 'size': 250000000},
#         {'name': 'GoInstant', 'size': 70000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'Jigsaw', 'size': 142000000},
#         {'name': 'Dimdim', 'size': 31000000},
#         {'name': 'Clipboard', 'size': 12000000}]}]},
#     {'name': 'Cisco',
#      'children': [{'name': 'Video',
#        'children': [{'name': 'BNI Video', 'size': 99000000},
#         {'name': 'Extend Media', 'size': 80000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'Securent', 'size': 100000000},
#         {'name': 'Metreos Corporation', 'size': 28000000},
#         {'name': 'Composite Software', 'size': 180000000}]},
#       {'name': 'Hardware + Software',
#        'children': [{'name': 'Pure Digital Technologies', 'size': 590000000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'Cloupia', 'size': 125000000},
#         {'name': 'Starent Networks', 'size': 2900000000},
#         {'name': 'Lightwire', 'size': 271000000},
#         {'name': 'JouleX', 'size': 107000000},
#         {'name': 'WhipTail', 'size': 415000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'WebEx', 'size': 3200000000}]},
#       {'name': 'Security',
#        'children': [{'name': 'Sourcefire', 'size': 2700000000},
#         {'name': 'IronPort Systems', 'size': 830000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'Tandberg', 'size': 3400000000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'PostPath', 'size': 215000000}]},
#       {'name': 'Web Hosting',
#        'children': [{'name': 'Navini Networks', 'size': 330000000},
#         {'name': 'Pure Networks', 'size': 120000000},
#         {'name': 'Tidal Software', 'size': 105000000},
#         {'name': 'Meraki', 'size': 1200000000},
#         {'name': 'Airespace', 'size': 450000000}]}]},
#     {'name': 'Oracle Corporation',
#      'children': [{'name': 'Software',
#        'children': [{'name': 'RightNow Technologies', 'size': 1500000000},
#         {'name': 'Taleo', 'size': 1900000000},
#         {'name': 'BigMachines', 'size': 400000000},
#         {'name': 'Agile Software', 'size': 495000000},
#         {'name': 'BEA Systems', 'size': 8500000000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'Siebel Systems', 'size': 5850000000},
#         {'name': 'Sun Microsystems', 'size': 7400000000},
#         {'name': 'Eloqua', 'size': 871000000},
#         {'name': 'Vitrue', 'size': 300000000},
#         {'name': 'MICROS Systems', 'size': 5300000000}]},
#       {'name': 'Service Provider',
#        'children': [{'name': 'Responsys', 'size': 1500000000}]},
#       {'name': 'Health',
#        'children': [{'name': 'Phase Forward', 'size': 685000000}]},
#       {'name': 'Analytics',
#        'children': [{'name': 'Xsigo', 'size': 220000000}]}]}]},
#   {'name': 'Software',
#    'value': 11622000000,
#    'children': [{'name': 'Microsoft',
#      'children': [{'name': 'Mobile',
#        'children': [{'name': 'Tellme', 'size': 800000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'Acompli', 'size': 200000000},
#         {'name': 'Danger', 'size': 500000000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'Parature', 'size': 100000000},
#         {'name': 'Yammer', 'size': 1200000000}]},
#       {'name': 'Hardware + Software',
#        'children': [{'name': 'VideoSurf', 'size': 100000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'Vicinity Corporation', 'size': 96000000},
#         {'name': 'aQuantive', 'size': 6400000000}]},
#       {'name': 'Service Provider',
#        'children': [{'name': 'Fast Search & Transfer', 'size': 1200000000},
#         {'name': 'Powerset', 'size': 100000000}]},
#       {'name': 'Security',
#        'children': [{'name': 'Whale Communications', 'size': 75000000}]},
#       {'name': 'Travel',
#        'children': [{'name': 'Farecast', 'size': 115000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'Greenfield Online', 'size': 486000000}]},
#       {'name': 'Analytics',
#        'children': [{'name': 'Equivio', 'size': 200000000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'jellyfish', 'size': 50000000}]}]}]},
#   {'name': 'Hardware + Software',
#    'value': 44384000000,
#    'children': [{'name': 'Hewlett-Packard',
#      'children': [{'name': 'Mobile',
#        'children': [{'name': 'Palm', 'size': 1200000000}]},
#       {'name': 'Software',
#        'children': [{'name': 'Shunra Software', 'size': 25000000},
#         {'name': '3PAR', 'size': 2350000000},
#         {'name': 'Opsware', 'size': 1600000000},
#         {'name': 'Lefthand Networks', 'size': 360000000},
#         {'name': 'Autonomy Corporation', 'size': 10200000000}]},
#       {'name': 'Hardware + Software',
#        'children': [{'name': 'VeriFone', 'size': 1180000000}]},
#       {'name': 'Enterprise Software',
#        'children': [{'name': 'EDS', 'size': 13900000000},
#         {'name': 'Mercury Interactive', 'size': 4500000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': '3Com', 'size': 2700000000}]},
#       {'name': 'Security',
#        'children': [{'name': 'ArcSight', 'size': 1500000000}]},
#       {'name': 'Media',
#        'children': [{'name': 'Melodeo', 'size': 30000000},
#         {'name': 'Snapfish', 'size': 300000000}]}]},
#     {'name': 'Apple',
#      'children': [{'name': 'Hardware + Software',
#        'children': [{'name': 'NeXT', 'size': 400000000},
#         {'name': 'Beats Electronics', 'size': 3000000000},
#         {'name': 'Intrinsity', 'size': 121000000}]},
#       {'name': 'Curated Web',
#        'children': [{'name': 'Cue', 'size': 50000000},
#         {'name': 'Concept.io', 'size': 30000000}]},
#       {'name': 'Service Provider',
#        'children': [{'name': 'WiFiSLAM', 'size': 20000000}]},
#       {'name': 'Security',
#        'children': [{'name': 'AuthenTec', 'size': 356000000}]},
#       {'name': 'Media', 'children': [{'name': 'Lala', 'size': 80000000}]},
#       {'name': 'Advertising',
#        'children': [{'name': 'Quattro Wireless', 'size': 275000000}]},
#       {'name': 'Social Media',
#        'children': [{'name': 'Color Labs Inc.', 'size': 7000000},
#         {'name': 'Topsy Labs', 'size': 200000000}]}]}]}]}

# %%
with open('chartPacking.json', 'w') as outfile:
    json.dump(finaljson, outfile)

# %%
# finaljson
